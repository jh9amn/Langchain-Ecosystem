# %% [markdown]
# #### Vector stores and Retriever
#
# The Langchain's vector store and retriever abstractions. These abstractions are desigend to support retrieval of data --  from (vector) databases and other sources -- for integration with LLM workflows. They are important for application that fetch data to be reasoned over as part of model inference, as in the case of retrieval - augmented generation.
#
# - Documents
# - Vector Stores
# - Retrievers

# %%
# !pip install langchain
# !pip install langchain-chroma
# !pip install langchain-groq
# Out:
# Requirement already satisfied: langchain in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (1.2.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.1 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from langchain) (1.2.7)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from langchain) (1.0.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from langchain) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (0.5.2)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.1->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.5)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.3.1)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.1)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (0.25.0)
# Requirement already satisfied: anyio in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (4.12.0)
# Requirement already satisfied: certifi in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (2.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (1.3.1)
# Requirement already satisfied: langchain-chroma in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (1.1.0)
# Requirement already satisfied: chromadb<2.0.0,>=1.3.5 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from langchain-chroma) (1.4.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.1.3 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from langchain-chroma) (1.2.7)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from langchain-chroma) (2.2.6)
# Requirement already satisfied: build>=1.0.3 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.3.0)
# Requirement already satisfied: pydantic>=1.9 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.12.5)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.40.0)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (5.4.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.15.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.23.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.39.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.39.1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.39.1)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.22.2)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.76.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.21.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (34.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (9.1.2)
# Requirement already satisfied: pyyaml>=6.0.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (6.0.3)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (5.2.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.11.5)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (14.2.0)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.25.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (0.5.2)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (25.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (3.0.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (0.25.0)
# Requirement already satisfied: anyio in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.12.0)
# Requirement already satisfied: certifi in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.0.9)
# Requirement already satisfied: idna in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.16.0)
# Requirement already satisfied: six>=1.5 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.9.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from pydantic>=1.9->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from pydantic>=1.9->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from pydantic>=1.9->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (2.3.0)
# Requirement already satisfied: pyproject_hooks in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from build>=1.0.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.2.0)
# Requirement already satisfied: colorama in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from build>=1.0.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.4.6)
# Requirement already satisfied: tomli>=1.1.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from build>=1.0.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.3.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.30.0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.46.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.9.0)
# Requirement already satisfied: requests-oauthlib in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.10)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (6.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.6.1)
# Requirement already satisfied: coloredlogs in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma) (25.12.19)
# Requirement already satisfied: protobuf in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma) (6.33.2)
# Requirement already satisfied: sympy in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.39.1 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.39.1)
# Requirement already satisfied: opentelemetry-proto==1.39.1 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.39.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.60b1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from rich>=10.11.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from rich>=10.11.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.1.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from tokenizers>=0.13.2->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.36.0)
# Requirement already satisfied: filelock in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.20.2)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2025.12.0)
# Requirement already satisfied: click>=8.0.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from typer>=0.9.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from typer>=0.9.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.7.1)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.2.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (15.0.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from anyio->httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.3.1)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma) (10.0)
# Requirement already satisfied: pyreadline3 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.5.4)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.3.0)
# Requirement already satisfied: langchain-groq in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (1.1.1)
# Requirement already satisfied: groq<1.0.0,>=0.30.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from langchain-groq) (0.37.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.1.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from langchain-groq) (1.2.7)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (4.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (2.12.5)
# Requirement already satisfied: sniffio in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (4.15.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from anyio<5,>=3.5.0->groq<1.0.0,>=0.30.0->langchain-groq) (1.3.1)
# Requirement already satisfied: idna>=2.8 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from anyio<5,>=3.5.0->groq<1.0.0,>=0.30.0->langchain-groq) (3.11)
# Requirement already satisfied: certifi in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-groq) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-groq) (0.5.2)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-groq) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-groq) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-groq) (9.1.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-groq) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.1.0->langchain-groq) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-groq) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-groq) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-groq) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-groq) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain-groq) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-groq) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-groq) (2.3.0)

# %% [markdown]
# ## Documents
#
# Langchain implements a Documents abstraction, which is intended to represent a unit of text and associated metadata. It has tow attributes:
#
# - page_content: A string representing the content;
# - metadata: A dict containing arbitrary metadata.
#
# The Metadata attribute can capture information about the source of the document, its relationship ot other documents, and other information. Note that an individual Document object often represents a chunk of larger document.
#
# Generate Some sample documents:

# %%
from langchain_core.documents import Document

doc = [
    Document(page_content="Hello, world!", metadata={"source": "greeting.txt"}),
    Document(page_content="LangChain is great for building applications with LLMs.", metadata={"source": "langchain.txt"}),
    Document(page_content="LLMs are powerful tools for natural language processing.", metadata={"source": "llm.txt"}),
    Document(page_content="Python is a versatile programming language.", metadata={"source": "python.txt"}),
    Document(page_content="Chroma is a vector database for storing embeddings.", metadata={"source": "chroma.txt"}),
]

# %%
print(doc)
# Out:
# [Document(metadata={'source': 'greeting.txt'}, page_content='Hello, world!'), Document(metadata={'source': 'langchain.txt'}, page_content='LangChain is great for building applications with LLMs.'), Document(metadata={'source': 'llm.txt'}, page_content='LLMs are powerful tools for natural language processing.'), Document(metadata={'source': 'python.txt'}, page_content='Python is a versatile programming language.'), Document(metadata={'source': 'chroma.txt'}, page_content='Chroma is a vector database for storing embeddings.')]

# %%
import os
from dotenv import load_dotenv
load_dotenv()

from langchain_groq import ChatGroq

groq_api_key = os.getenv("GROQ_API_KEY")
os.environ["HUGGINGFACEHUB_API_TOKEN"] = os.getenv("HUGGINGFACEHUB_API_TOKEN")

llm = ChatGroq(groq_api_key = groq_api_key, model = "llama-3.1-8b-instant")
llm
# Out:
# ChatGroq(profile={'max_input_tokens': 131072, 'max_output_tokens': 8192, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True}, client=<groq.resources.chat.completions.Completions object at 0x00000271F43403A0>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x00000271F43402B0>, model_name='llama-3.1-8b-instant', model_kwargs={}, groq_api_key=SecretStr('**********'))

# %%
# !pip install langchain_huggingface
# Out:
# Requirement already satisfied: langchain_huggingface in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (1.2.0)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.33.4 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from langchain_huggingface) (0.36.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from langchain_huggingface) (1.2.7)
# Requirement already satisfied: tokenizers<1.0.0,>=0.19.1 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from langchain_huggingface) (0.22.2)
# Requirement already satisfied: filelock in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain_huggingface) (3.20.2)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain_huggingface) (2025.12.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain_huggingface) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain_huggingface) (6.0.3)
# Requirement already satisfied: requests in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain_huggingface) (2.32.5)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain_huggingface) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain_huggingface) (4.15.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from langchain-core<2.0.0,>=1.2.0->langchain_huggingface) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from langchain-core<2.0.0,>=1.2.0->langchain_huggingface) (0.5.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from langchain-core<2.0.0,>=1.2.0->langchain_huggingface) (2.12.5)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from langchain-core<2.0.0,>=1.2.0->langchain_huggingface) (9.1.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from langchain-core<2.0.0,>=1.2.0->langchain_huggingface) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.0->langchain_huggingface) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain_huggingface) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain_huggingface) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain_huggingface) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain_huggingface) (0.25.0)
# Requirement already satisfied: anyio in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain_huggingface) (4.12.0)
# Requirement already satisfied: certifi in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain_huggingface) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain_huggingface) (1.0.9)
# Requirement already satisfied: idna in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain_huggingface) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain_huggingface) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.0->langchain_huggingface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.0->langchain_huggingface) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.0->langchain_huggingface) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from requests->huggingface-hub<1.0.0,>=0.33.4->langchain_huggingface) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from requests->huggingface-hub<1.0.0,>=0.33.4->langchain_huggingface) (2.3.0)
# Requirement already satisfied: colorama in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from tqdm>=4.42.1->huggingface-hub<1.0.0,>=0.33.4->langchain_huggingface) (0.4.6)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\amank\.conda\envs\langchain_env\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain_huggingface) (1.3.1)

# %%
from langchain_huggingface import HuggingFaceEmbeddings
embeddings = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")

# %%
## Vector Store 
from langchain_chroma import Chroma

vectorstore = Chroma.from_documents(documents=doc, embedding=embeddings)
vectorstore

# %%
vectorstore.similarity_search("programming")
# Out:
# [Document(id='3d4594d0-3587-4e7d-a3f5-049df7c392c1', metadata={'source': 'python.txt'}, page_content='Python is a versatile programming language.'),
#  Document(id='296b3abf-e19b-4327-9d77-6a606861fa40', metadata={'source': 'python.txt'}, page_content='Python is a versatile programming language.'),
#  Document(id='9a124622-866b-40ac-ab5e-d09dc21ba46a', metadata={'source': 'llm.txt'}, page_content='LLMs are powerful tools for natural language processing.'),
#  Document(id='a7f48f0b-1fd3-467a-82fd-cda58969be2b', metadata={'source': 'llm.txt'}, page_content='LLMs are powerful tools for natural language processing.')]

# %%
## Async query
await vectorstore.asimilarity_search("programming")
# Out:
# [Document(id='3d4594d0-3587-4e7d-a3f5-049df7c392c1', metadata={'source': 'python.txt'}, page_content='Python is a versatile programming language.'),
#  Document(id='296b3abf-e19b-4327-9d77-6a606861fa40', metadata={'source': 'python.txt'}, page_content='Python is a versatile programming language.'),
#  Document(id='9a124622-866b-40ac-ab5e-d09dc21ba46a', metadata={'source': 'llm.txt'}, page_content='LLMs are powerful tools for natural language processing.'),
#  Document(id='a7f48f0b-1fd3-467a-82fd-cda58969be2b', metadata={'source': 'llm.txt'}, page_content='LLMs are powerful tools for natural language processing.')]

# %%
## Similarity search with score
vectorstore.similarity_search_with_score("programming")
# Out:
# [(Document(id='3d4594d0-3587-4e7d-a3f5-049df7c392c1', metadata={'source': 'python.txt'}, page_content='Python is a versatile programming language.'),
#   0.8644969463348389),
#  (Document(id='296b3abf-e19b-4327-9d77-6a606861fa40', metadata={'source': 'python.txt'}, page_content='Python is a versatile programming language.'),
#   0.8644969463348389),
#  (Document(id='9a124622-866b-40ac-ab5e-d09dc21ba46a', metadata={'source': 'llm.txt'}, page_content='LLMs are powerful tools for natural language processing.'),
#   1.5134737491607666),
#  (Document(id='a7f48f0b-1fd3-467a-82fd-cda58969be2b', metadata={'source': 'llm.txt'}, page_content='LLMs are powerful tools for natural language processing.'),
#   1.5134737491607666)]

# %% [markdown]
# ## Retrievers
#
# LangChain vectorStore objects do not subclass Runnable, and so cannot immediately be integrated into LangChain Expression Language chains.
#
# LangChain Retrievers are Runnables, so they implement a standard set fo methods. (eg, synchronous and asynchronous invoke and batch operations)  and are designed to be incorporated in LCEL chains.
#
# We can create a simple version of this ourselvesm withour subclassing Retriever. If we choose what method we wish to use to retrieve documents, we can create a runnable easily. Below we will build one around the similarity_search method:

# %%
from typing import List

from langchain_core.documents import Document
from langchain_core.runnables import RunnableLambda

## 1st way
retriever = RunnableLambda(vectorstore.similarity_search).bind(k=1)
retriever.batch(["cat", "dog"])
# Out:
# [[Document(id='d4313a14-ffe6-42ea-969a-b531b1bda685', metadata={'source': 'greeting.txt'}, page_content='Hello, world!')],
#  [Document(id='d4313a14-ffe6-42ea-969a-b531b1bda685', metadata={'source': 'greeting.txt'}, page_content='Hello, world!')]]

# %% [markdown]
# Vectorstores implement an as_retriever method that will generate a Retriever, specifically a VectorStoreRetriever. These retriever include specific search_type and search_kwargs attributes that identify what methods of the underlying vector store to call, and how to parameterize them. For instance, we can replicate the above with the following.

# %%
## 2nd way
retriever = vectorstore.as_retriever(
    search_type = "similarity",
    search_kwargs= {"k": 1}
)

retriever.batch(["cat", "dog"])
# Out:
# [[Document(id='d4313a14-ffe6-42ea-969a-b531b1bda685', metadata={'source': 'greeting.txt'}, page_content='Hello, world!')],
#  [Document(id='d4313a14-ffe6-42ea-969a-b531b1bda685', metadata={'source': 'greeting.txt'}, page_content='Hello, world!')]]

# %%
## Integrate Retriever with chain
## RAG Chain - Retrieval Augmented Generation Chain 
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnablePassthrough

message = """
Answer this question using the provided context only.

{question}

Context:
{context}
"""

prompt = ChatPromptTemplate.from_messages([("human", message)])

rag_chain = {"context": retriever, "question": RunnablePassthrough()} | prompt | llm

response = rag_chain.invoke("tell me about dogs")
response.content
# Out:
# 'There is no information about dogs in the provided context. The context appears to be a reference to a document with a greeting message, but it does not contain any information about dogs.'
